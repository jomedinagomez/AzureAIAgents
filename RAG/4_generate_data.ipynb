# %% [markdown]
# ### Loading Libraries

# %%
import os
import pandas as pd
from dotenv import load_dotenv

from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.testset import TestsetGenerator

from langchain_community.document_loaders import DirectoryLoader,DataFrameLoader

load_dotenv(override=True) # take environment variables from .env.
# Out:
# True

# %% [markdown]
# ### Loading Processed data

# %%
path = "data/processed/files/"
filelist = os.listdir(path)

combined_df = pd.DataFrame()
for filename in filelist:
    single_df = pd.read_parquet(path + filename)
    combined_df = pd.concat([combined_df, single_df])
combined_df =combined_df.reset_index(drop=True)

combined_df['text'] = "Title: "+ combined_df['title'].astype(str) + "\n" + "Content: "+ combined_df['content'].astype(str) 
combined_df = combined_df.drop(columns = ["title","content","title_vector","content_vector","preprocessing_pipeline"])

combined_df = combined_df.sample(500).reset_index(drop=True)

# %% [markdown]
# ### Loading environment variables

# %%
os.environ["AZURE_OPENAI_API_KEY"] = os.environ["AZURE_OPENAI_API_KEY"]

# other configuration
azure_configs = {
    "base_url":os.environ["AZURE_OPENAI_ENDPOINT"],  # your endpoint
    "model_deployment": "gpt-4o",  # your model deployment name
    "model_name": "gpt-4o",  # your model name
    "embedding_deployment": "text-embedding-3-small",  # your embedding deployment name
    "embedding_name": "text-embedding-3-small",  # your embedding name
}

# %% [markdown]
# ### Creating generator

# %%
generator_llm = LangchainLLMWrapper(AzureChatOpenAI(
    openai_api_version="2024-10-21",
    azure_endpoint=azure_configs["base_url"],
    azure_deployment=azure_configs["model_deployment"],
    model=azure_configs["model_name"],
    validate_base_url=False,
))

# init the embeddings for answer_relevancy, answer_correctness and answer_similarity
generator_embeddings = LangchainEmbeddingsWrapper(AzureOpenAIEmbeddings(
    openai_api_version="2024-10-21",
    azure_endpoint=azure_configs["base_url"],
    azure_deployment=azure_configs["embedding_deployment"],
    model=azure_configs["embedding_name"],
))

# %% [markdown]
# ### Running generator

# %%
loader = DataFrameLoader(combined_df)
docs = loader.load()

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=100)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/440 [00:00<?, ?it/s]
# Applying HeadlineSplitter:   0%|          | 0/500 [00:00<?, ?it/s]
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# Applying SummaryExtractor:   0%|          | 0/727 [00:00<?, ?it/s]
# Property 'summary' already exists in node '65afc4'. Skipping!
# Property 'summary' already exists in node 'f14cbe'. Skipping!
# Property 'summary' already exists in node '3caf85'. Skipping!
# Property 'summary' already exists in node 'abbd50'. Skipping!
# Property 'summary' already exists in node 'ea683f'. Skipping!
# Property 'summary' already exists in node 'ade532'. Skipping!
# Property 'summary' already exists in node 'd6a911'. Skipping!
# Property 'summary' already exists in node '58e512'. Skipping!
# Property 'summary' already exists in node 'cf9659'. Skipping!
# Property 'summary' already exists in node '02e2b3'. Skipping!
# Property 'summary' already exists in node '5b06d8'. Skipping!
# Property 'summary' already exists in node 'd45f57'. Skipping!
# Property 'summary' already exists in node 'f23f0d'. Skipping!
# Property 'summary' already exists in node '0b6e6e'. Skipping!
# Property 'summary' already exists in node 'e1314f'. Skipping!
# Property 'summary' already exists in node '3e77ea'. Skipping!
# Property 'summary' already exists in node '8605a0'. Skipping!
# Property 'summary' already exists in node 'f2ae8c'. Skipping!
# Property 'summary' already exists in node 'b52312'. Skipping!
# Property 'summary' already exists in node '2324cd'. Skipping!
# Property 'summary' already exists in node '78f9a9'. Skipping!
# Property 'summary' already exists in node 'd93196'. Skipping!
# Property 'summary' already exists in node '99074c'. Skipping!
# Property 'summary' already exists in node '4d5e08'. Skipping!
# Property 'summary' already exists in node '617883'. Skipping!
# Property 'summary' already exists in node 'c302be'. Skipping!
# Property 'summary' already exists in node '587d54'. Skipping!
# Property 'summary' already exists in node '0eb2ce'. Skipping!
# Property 'summary' already exists in node '431a07'. Skipping!
# Property 'summary' already exists in node 'f3a490'. Skipping!
# Property 'summary' already exists in node '8a14f3'. Skipping!
# Property 'summary' already exists in node '32e47e'. Skipping!
# Property 'summary' already exists in node '59020c'. Skipping!
# Property 'summary' already exists in node 'caeb66'. Skipping!
# Property 'summary' already exists in node 'd112bd'. Skipping!
# Property 'summary' already exists in node '123f1a'. Skipping!
# Property 'summary' already exists in node 'cb670b'. Skipping!
# Property 'summary' already exists in node '2122be'. Skipping!
# Property 'summary' already exists in node '7f3a9f'. Skipping!
# Property 'summary' already exists in node 'f794da'. Skipping!
# Property 'summary' already exists in node '2b54e7'. Skipping!
# Property 'summary' already exists in node 'cb9a3d'. Skipping!
# Property 'summary' already exists in node 'dc7efe'. Skipping!
# Property 'summary' already exists in node '3e32c1'. Skipping!
# Property 'summary' already exists in node 'f07374'. Skipping!
# Property 'summary' already exists in node 'f59bf8'. Skipping!
# Property 'summary' already exists in node '3e267b'. Skipping!
# Property 'summary' already exists in node 'ca33d0'. Skipping!
# Property 'summary' already exists in node '568bc5'. Skipping!
# Property 'summary' already exists in node 'a0b1e1'. Skipping!
# Property 'summary' already exists in node 'c83bb4'. Skipping!
# Property 'summary' already exists in node '1f3c9d'. Skipping!
# Property 'summary' already exists in node '9ddde3'. Skipping!
# Property 'summary' already exists in node 'e1d941'. Skipping!
# Property 'summary' already exists in node 'ca5a15'. Skipping!
# Property 'summary' already exists in node 'de3f0e'. Skipping!
# Property 'summary' already exists in node 'bc21be'. Skipping!
# Property 'summary' already exists in node '4a839b'. Skipping!
# Property 'summary' already exists in node '55bc34'. Skipping!
# Property 'summary' already exists in node '035194'. Skipping!
# Property 'summary' already exists in node 'ca1021'. Skipping!
# Property 'summary' already exists in node 'b8cae6'. Skipping!
# Property 'summary' already exists in node 'c5ee75'. Skipping!
# Property 'summary' already exists in node '0caa47'. Skipping!
# Property 'summary' already exists in node 'c51608'. Skipping!
# Property 'summary' already exists in node '25d7d9'. Skipping!
# Property 'summary' already exists in node '6f25b9'. Skipping!
# Property 'summary' already exists in node 'b55929'. Skipping!
# Property 'summary' already exists in node 'eb01f4'. Skipping!
# Property 'summary' already exists in node '6c101b'. Skipping!
# Property 'summary' already exists in node '48ed04'. Skipping!
# Property 'summary' already exists in node 'af9458'. Skipping!
# Property 'summary' already exists in node 'b81b48'. Skipping!
# Property 'summary' already exists in node '74abaf'. Skipping!
# Property 'summary' already exists in node 'f402d0'. Skipping!
# Property 'summary' already exists in node '7fb057'. Skipping!
# Property 'summary' already exists in node '004c5f'. Skipping!
# Property 'summary' already exists in node '7a8643'. Skipping!
# Property 'summary' already exists in node '1ec9df'. Skipping!
# Property 'summary' already exists in node 'fd9dab'. Skipping!
# Property 'summary' already exists in node '966301'. Skipping!
# Property 'summary' already exists in node '3a2672'. Skipping!
# Property 'summary' already exists in node '86cb58'. Skipping!
# Property 'summary' already exists in node '080727'. Skipping!
# Property 'summary' already exists in node '73027d'. Skipping!
# Property 'summary' already exists in node 'a2e838'. Skipping!
# Property 'summary' already exists in node '296c17'. Skipping!
# Property 'summary' already exists in node 'c61555'. Skipping!
# Property 'summary' already exists in node 'db5a78'. Skipping!
# Property 'summary' already exists in node 'adb245'. Skipping!
# Property 'summary' already exists in node '6e9f6a'. Skipping!
# Property 'summary' already exists in node '9cffdf'. Skipping!
# Property 'summary' already exists in node '257cc4'. Skipping!
# Property 'summary' already exists in node 'e2b06f'. Skipping!
# Property 'summary' already exists in node '4a971c'. Skipping!
# Property 'summary' already exists in node '6f2f70'. Skipping!
# Property 'summary' already exists in node '3588e9'. Skipping!
# Property 'summary' already exists in node '7e5e0c'. Skipping!
# Property 'summary' already exists in node '742adb'. Skipping!
# Property 'summary' already exists in node '3dd719'. Skipping!
# Property 'summary' already exists in node 'd065ea'. Skipping!
# Property 'summary' already exists in node 'cb2253'. Skipping!
# Property 'summary' already exists in node '1eee2e'. Skipping!
# Property 'summary' already exists in node '125eb9'. Skipping!
# Property 'summary' already exists in node 'c63d79'. Skipping!
# Property 'summary' already exists in node 'c19aa4'. Skipping!
# Property 'summary' already exists in node '250fad'. Skipping!
# Property 'summary' already exists in node '9abd67'. Skipping!
# Property 'summary' already exists in node 'd4c679'. Skipping!
# Property 'summary' already exists in node '362a30'. Skipping!
# Property 'summary' already exists in node 'e8f41f'. Skipping!
# Property 'summary' already exists in node '165128'. Skipping!
# Property 'summary' already exists in node '1860e1'. Skipping!
# Property 'summary' already exists in node 'd8f2bc'. Skipping!
# Property 'summary' already exists in node '54fb95'. Skipping!
# Property 'summary' already exists in node '11f261'. Skipping!
# Property 'summary' already exists in node '08573c'. Skipping!
# Property 'summary' already exists in node '4a346b'. Skipping!
# Property 'summary' already exists in node 'f29bec'. Skipping!
# Property 'summary' already exists in node '288879'. Skipping!
# Property 'summary' already exists in node '702f2a'. Skipping!
# Property 'summary' already exists in node 'e61e52'. Skipping!
# Property 'summary' already exists in node '40c36c'. Skipping!
# Property 'summary' already exists in node '885658'. Skipping!
# Property 'summary' already exists in node '246a10'. Skipping!
# Property 'summary' already exists in node 'c030eb'. Skipping!
# Property 'summary' already exists in node '8cf0f9'. Skipping!
# Property 'summary' already exists in node '2ae16f'. Skipping!
# Property 'summary' already exists in node 'c5d1d4'. Skipping!
# Property 'summary' already exists in node '92114a'. Skipping!
# Property 'summary' already exists in node '93a2d4'. Skipping!
# Property 'summary' already exists in node '8451e2'. Skipping!
# Property 'summary' already exists in node 'dbd342'. Skipping!
# Property 'summary' already exists in node '23facb'. Skipping!
# Property 'summary' already exists in node 'f1def6'. Skipping!
# Property 'summary' already exists in node '8daf6a'. Skipping!
# Property 'summary' already exists in node '6b1530'. Skipping!
# Property 'summary' already exists in node '01473f'. Skipping!
# Property 'summary' already exists in node 'c5643d'. Skipping!
# Property 'summary' already exists in node 'fcd06a'. Skipping!
# Property 'summary' already exists in node 'f735b8'. Skipping!
# Property 'summary' already exists in node '5549fb'. Skipping!
# Property 'summary' already exists in node '7ad6ad'. Skipping!
# Property 'summary' already exists in node 'be3187'. Skipping!
# Property 'summary' already exists in node '5eee63'. Skipping!
# Property 'summary' already exists in node 'e71349'. Skipping!
# Property 'summary' already exists in node '46901b'. Skipping!
# Property 'summary' already exists in node '12f195'. Skipping!
# Property 'summary' already exists in node '4e22e6'. Skipping!
# Property 'summary' already exists in node 'da5d15'. Skipping!
# Property 'summary' already exists in node '47099c'. Skipping!
# Property 'summary' already exists in node 'f1a443'. Skipping!
# Property 'summary' already exists in node 'ecbf95'. Skipping!
# Property 'summary' already exists in node 'f49465'. Skipping!
# Property 'summary' already exists in node 'ac5796'. Skipping!
# Property 'summary' already exists in node 'cb2ce4'. Skipping!
# Property 'summary' already exists in node 'de07c6'. Skipping!
# Property 'summary' already exists in node '542241'. Skipping!
# Property 'summary' already exists in node '87b8e1'. Skipping!
# Property 'summary' already exists in node '33aaa7'. Skipping!
# Property 'summary' already exists in node '50a335'. Skipping!
# Property 'summary' already exists in node '41a571'. Skipping!
# Property 'summary' already exists in node '8a3520'. Skipping!
# Property 'summary' already exists in node '2a71fc'. Skipping!
# Property 'summary' already exists in node '6db2ac'. Skipping!
# Property 'summary' already exists in node '6b79cc'. Skipping!
# Property 'summary' already exists in node '23af3e'. Skipping!
# Property 'summary' already exists in node '039f38'. Skipping!
# Property 'summary' already exists in node 'ff615b'. Skipping!
# Property 'summary' already exists in node 'cbca2b'. Skipping!
# Property 'summary' already exists in node '782ad7'. Skipping!
# Property 'summary' already exists in node '54253c'. Skipping!
# Property 'summary' already exists in node 'b23f44'. Skipping!
# Property 'summary' already exists in node '5d6e2d'. Skipping!
# Property 'summary' already exists in node 'bc02e9'. Skipping!
# Property 'summary' already exists in node '1c7cd7'. Skipping!
# Property 'summary' already exists in node '7979be'. Skipping!
# Property 'summary' already exists in node 'e87756'. Skipping!
# Property 'summary' already exists in node 'db6036'. Skipping!
# Property 'summary' already exists in node '7753bb'. Skipping!
# Property 'summary' already exists in node '5a0402'. Skipping!
# Property 'summary' already exists in node '70cf05'. Skipping!
# Property 'summary' already exists in node '9bc8d2'. Skipping!
# Property 'summary' already exists in node '5cfe4a'. Skipping!
# Property 'summary' already exists in node '836d03'. Skipping!
# Property 'summary' already exists in node 'f2f4d1'. Skipping!
# Property 'summary' already exists in node '0446e8'. Skipping!
# Property 'summary' already exists in node '08450e'. Skipping!
# Property 'summary' already exists in node '8c9252'. Skipping!
# Property 'summary' already exists in node '1dbbd2'. Skipping!
# Property 'summary' already exists in node 'dc3cf8'. Skipping!
# Property 'summary' already exists in node 'be3c66'. Skipping!
# Property 'summary' already exists in node '9f9758'. Skipping!
# Property 'summary' already exists in node '6fdf3e'. Skipping!
# Property 'summary' already exists in node '329f13'. Skipping!
# Property 'summary' already exists in node '2d101d'. Skipping!
# Property 'summary' already exists in node '3fd47c'. Skipping!
# Property 'summary' already exists in node '95a732'. Skipping!
# Property 'summary' already exists in node 'cd191f'. Skipping!
# Property 'summary' already exists in node '634217'. Skipping!
# Property 'summary' already exists in node '737fbd'. Skipping!
# Property 'summary' already exists in node 'e063b8'. Skipping!
# Property 'summary' already exists in node '78422d'. Skipping!
# Property 'summary' already exists in node 'df0783'. Skipping!
# Property 'summary' already exists in node '0c901b'. Skipping!
# Property 'summary' already exists in node '74de17'. Skipping!
# Property 'summary' already exists in node '050e13'. Skipping!
# Property 'summary' already exists in node '9ff964'. Skipping!
# Property 'summary' already exists in node '402e25'. Skipping!
# Property 'summary' already exists in node '1a9f16'. Skipping!
# Property 'summary' already exists in node '7143c5'. Skipping!
# Property 'summary' already exists in node 'a57316'. Skipping!
# Property 'summary' already exists in node '935b79'. Skipping!
# Property 'summary' already exists in node '32b4ff'. Skipping!
# Property 'summary' already exists in node '00ff03'. Skipping!
# Property 'summary' already exists in node 'debd2c'. Skipping!
# Property 'summary' already exists in node '6ec456'. Skipping!
# Property 'summary' already exists in node 'a8826d'. Skipping!
# Property 'summary' already exists in node '3c7616'. Skipping!
# Property 'summary' already exists in node '2e72a6'. Skipping!
# Property 'summary' already exists in node '1e1d89'. Skipping!
# Property 'summary' already exists in node '3bfcad'. Skipping!
# Property 'summary' already exists in node '065514'. Skipping!
# Property 'summary' already exists in node '1bbda9'. Skipping!
# Property 'summary' already exists in node 'ac9579'. Skipping!
# Property 'summary' already exists in node '97a6bf'. Skipping!
# Property 'summary' already exists in node '62884b'. Skipping!
# Property 'summary' already exists in node 'bf4017'. Skipping!
# Property 'summary' already exists in node 'f7ad45'. Skipping!
# Property 'summary' already exists in node '41e982'. Skipping!
# Property 'summary' already exists in node '3144ed'. Skipping!
# Property 'summary' already exists in node '1d8694'. Skipping!
# Property 'summary' already exists in node 'b9daa6'. Skipping!
# Property 'summary' already exists in node 'a314fa'. Skipping!
# Property 'summary' already exists in node '1a4b2a'. Skipping!
# Property 'summary' already exists in node '78011e'. Skipping!
# Property 'summary' already exists in node '6abe07'. Skipping!
# Property 'summary' already exists in node '0f6004'. Skipping!
# Property 'summary' already exists in node '22811b'. Skipping!
# Property 'summary' already exists in node 'd88afb'. Skipping!
# Property 'summary' already exists in node '90643d'. Skipping!
# Property 'summary' already exists in node 'a274d8'. Skipping!
# Property 'summary' already exists in node '4c4a88'. Skipping!
# Property 'summary' already exists in node '209693'. Skipping!
# Property 'summary' already exists in node 'edf5e8'. Skipping!
# Property 'summary' already exists in node 'd04f8d'. Skipping!
# Property 'summary' already exists in node 'ed1f88'. Skipping!
# Property 'summary' already exists in node 'd5dc3a'. Skipping!
# Property 'summary' already exists in node '62e768'. Skipping!
# Property 'summary' already exists in node '75738a'. Skipping!
# Property 'summary' already exists in node '1b4cdb'. Skipping!
# Property 'summary' already exists in node '1e5dca'. Skipping!
# Property 'summary' already exists in node '7ae90f'. Skipping!
# Property 'summary' already exists in node '47fd70'. Skipping!
# Property 'summary' already exists in node 'd9fab3'. Skipping!
# Property 'summary' already exists in node '4ea932'. Skipping!
# Property 'summary' already exists in node '507ee1'. Skipping!
# Property 'summary' already exists in node 'fe6baa'. Skipping!
# Property 'summary' already exists in node '55c837'. Skipping!
# Property 'summary' already exists in node '487979'. Skipping!
# Property 'summary' already exists in node 'bf16e7'. Skipping!
# Property 'summary' already exists in node 'cce4db'. Skipping!
# Property 'summary' already exists in node '6e349d'. Skipping!
# Property 'summary' already exists in node '8f8d78'. Skipping!
# Property 'summary' already exists in node '8af988'. Skipping!
# Property 'summary' already exists in node 'b1511b'. Skipping!
# Property 'summary' already exists in node 'e42b0b'. Skipping!
# Property 'summary' already exists in node 'ef02b1'. Skipping!
# Property 'summary' already exists in node 'b3fadf'. Skipping!
# Property 'summary' already exists in node '8a600e'. Skipping!
# Property 'summary' already exists in node '4c2a84'. Skipping!
# Property 'summary' already exists in node '79b707'. Skipping!
# Property 'summary' already exists in node '160ad0'. Skipping!
# Property 'summary' already exists in node 'd645fa'. Skipping!
# Property 'summary' already exists in node '0f69e8'. Skipping!
# Property 'summary' already exists in node '729295'. Skipping!
# Property 'summary' already exists in node 'caafc6'. Skipping!
# Property 'summary' already exists in node '7a9e18'. Skipping!
# Property 'summary' already exists in node 'ce79ca'. Skipping!
# Property 'summary' already exists in node '2b54dd'. Skipping!
# Property 'summary' already exists in node '83c9b9'. Skipping!
# Property 'summary' already exists in node 'c1f910'. Skipping!
# Property 'summary' already exists in node '806864'. Skipping!
# Property 'summary' already exists in node '725d28'. Skipping!
# Property 'summary' already exists in node '9b2a7c'. Skipping!
# Property 'summary' already exists in node 'c97266'. Skipping!
# Property 'summary' already exists in node '7c7018'. Skipping!
# Applying CustomNodeFilter:   0%|          | 0/320 [00:00<?, ?it/s]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/1253 [00:00<?, ?it/s]
# Property 'summary_embedding' already exists in node '65afc4'. Skipping!
# Property 'summary_embedding' already exists in node 'f14cbe'. Skipping!
# Property 'summary_embedding' already exists in node 'ade532'. Skipping!
# Property 'summary_embedding' already exists in node 'ea683f'. Skipping!
# Property 'summary_embedding' already exists in node '99074c'. Skipping!
# Property 'summary_embedding' already exists in node '0b6e6e'. Skipping!
# Property 'summary_embedding' already exists in node 'd6a911'. Skipping!
# Property 'summary_embedding' already exists in node '3caf85'. Skipping!
# Property 'summary_embedding' already exists in node 'cf9659'. Skipping!
# Property 'summary_embedding' already exists in node 'e1314f'. Skipping!
# Property 'summary_embedding' already exists in node 'abbd50'. Skipping!
# Property 'summary_embedding' already exists in node '02e2b3'. Skipping!
# Property 'summary_embedding' already exists in node '58e512'. Skipping!
# Property 'summary_embedding' already exists in node 'f2ae8c'. Skipping!
# Property 'summary_embedding' already exists in node 'd45f57'. Skipping!
# Property 'summary_embedding' already exists in node '2324cd'. Skipping!
# Property 'summary_embedding' already exists in node 'f23f0d'. Skipping!
# Property 'summary_embedding' already exists in node 'b52312'. Skipping!
# Property 'summary_embedding' already exists in node '5b06d8'. Skipping!
# Property 'summary_embedding' already exists in node '8605a0'. Skipping!
# Property 'summary_embedding' already exists in node '3e77ea'. Skipping!
# Property 'summary_embedding' already exists in node '78f9a9'. Skipping!
# Property 'summary_embedding' already exists in node '617883'. Skipping!
# Property 'summary_embedding' already exists in node 'c302be'. Skipping!
# Property 'summary_embedding' already exists in node 'd93196'. Skipping!
# Property 'summary_embedding' already exists in node '431a07'. Skipping!
# Property 'summary_embedding' already exists in node '8a14f3'. Skipping!
# Property 'summary_embedding' already exists in node '587d54'. Skipping!
# Property 'summary_embedding' already exists in node '0eb2ce'. Skipping!
# Property 'summary_embedding' already exists in node '4d5e08'. Skipping!
# Property 'summary_embedding' already exists in node '59020c'. Skipping!
# Property 'summary_embedding' already exists in node 'f3a490'. Skipping!
# Property 'summary_embedding' already exists in node 'd112bd'. Skipping!
# Property 'summary_embedding' already exists in node '32e47e'. Skipping!
# Property 'summary_embedding' already exists in node '568bc5'. Skipping!
# Property 'summary_embedding' already exists in node '123f1a'. Skipping!
# Property 'summary_embedding' already exists in node 'caeb66'. Skipping!
# Property 'summary_embedding' already exists in node '2122be'. Skipping!
# Property 'summary_embedding' already exists in node '2b54e7'. Skipping!
# Property 'summary_embedding' already exists in node '9ddde3'. Skipping!
# Property 'summary_embedding' already exists in node 'cb670b'. Skipping!
# Property 'summary_embedding' already exists in node 'dc7efe'. Skipping!
# Property 'summary_embedding' already exists in node 'f794da'. Skipping!
# Property 'summary_embedding' already exists in node 'cb9a3d'. Skipping!
# Property 'summary_embedding' already exists in node '7f3a9f'. Skipping!
# Property 'summary_embedding' already exists in node 'f59bf8'. Skipping!
# Property 'summary_embedding' already exists in node '1f3c9d'. Skipping!
# Property 'summary_embedding' already exists in node 'c83bb4'. Skipping!
# Property 'summary_embedding' already exists in node '3e32c1'. Skipping!
# Property 'summary_embedding' already exists in node 'f07374'. Skipping!
# Property 'summary_embedding' already exists in node 'ca33d0'. Skipping!
# Property 'summary_embedding' already exists in node 'a0b1e1'. Skipping!
# Property 'summary_embedding' already exists in node '3e267b'. Skipping!
# Property 'summary_embedding' already exists in node 'c5ee75'. Skipping!
# Property 'summary_embedding' already exists in node 'ca1021'. Skipping!
# Property 'summary_embedding' already exists in node 'de3f0e'. Skipping!
# Property 'summary_embedding' already exists in node '55bc34'. Skipping!
# Property 'summary_embedding' already exists in node '25d7d9'. Skipping!
# Property 'summary_embedding' already exists in node '6f25b9'. Skipping!
# Property 'summary_embedding' already exists in node 'b55929'. Skipping!
# Property 'summary_embedding' already exists in node '48ed04'. Skipping!
# Property 'summary_embedding' already exists in node 'b8cae6'. Skipping!
# Property 'summary_embedding' already exists in node '4a839b'. Skipping!
# Property 'summary_embedding' already exists in node 'e1d941'. Skipping!
# Property 'summary_embedding' already exists in node '0caa47'. Skipping!
# Property 'summary_embedding' already exists in node 'ca5a15'. Skipping!
# Property 'summary_embedding' already exists in node 'c51608'. Skipping!
# Property 'summary_embedding' already exists in node '035194'. Skipping!
# Property 'summary_embedding' already exists in node 'bc21be'. Skipping!
# Property 'summary_embedding' already exists in node 'a2e838'. Skipping!
# Property 'summary_embedding' already exists in node '7fb057'. Skipping!
# Property 'summary_embedding' already exists in node '1ec9df'. Skipping!
# Property 'summary_embedding' already exists in node 'b81b48'. Skipping!
# Property 'summary_embedding' already exists in node '74abaf'. Skipping!
# Property 'summary_embedding' already exists in node 'af9458'. Skipping!
# Property 'summary_embedding' already exists in node 'f402d0'. Skipping!
# Property 'summary_embedding' already exists in node '6c101b'. Skipping!
# Property 'summary_embedding' already exists in node 'eb01f4'. Skipping!
# Property 'summary_embedding' already exists in node '004c5f'. Skipping!
# Property 'summary_embedding' already exists in node '86cb58'. Skipping!
# Property 'summary_embedding' already exists in node '966301'. Skipping!
# Property 'summary_embedding' already exists in node '080727'. Skipping!
# Property 'summary_embedding' already exists in node 'c61555'. Skipping!
# Property 'summary_embedding' already exists in node '73027d'. Skipping!
# Property 'summary_embedding' already exists in node '7a8643'. Skipping!
# Property 'summary_embedding' already exists in node '3a2672'. Skipping!
# Property 'summary_embedding' already exists in node 'fd9dab'. Skipping!
# Property 'summary_embedding' already exists in node 'adb245'. Skipping!
# Property 'summary_embedding' already exists in node '6e9f6a'. Skipping!
# Property 'summary_embedding' already exists in node '296c17'. Skipping!
# Property 'summary_embedding' already exists in node '9cffdf'. Skipping!
# Property 'summary_embedding' already exists in node '3588e9'. Skipping!
# Property 'summary_embedding' already exists in node 'db5a78'. Skipping!
# Property 'summary_embedding' already exists in node '257cc4'. Skipping!
# Property 'summary_embedding' already exists in node '1860e1'. Skipping!
# Property 'summary_embedding' already exists in node 'e2b06f'. Skipping!
# Property 'summary_embedding' already exists in node 'd065ea'. Skipping!
# Property 'summary_embedding' already exists in node '6f2f70'. Skipping!
# Property 'summary_embedding' already exists in node '7e5e0c'. Skipping!
# Property 'summary_embedding' already exists in node '125eb9'. Skipping!
# Property 'summary_embedding' already exists in node 'd4c679'. Skipping!
# Property 'summary_embedding' already exists in node '3dd719'. Skipping!
# Property 'summary_embedding' already exists in node '4a971c'. Skipping!
# Property 'summary_embedding' already exists in node '742adb'. Skipping!
# Property 'summary_embedding' already exists in node '9abd67'. Skipping!
# Property 'summary_embedding' already exists in node 'cb2253'. Skipping!
# Property 'summary_embedding' already exists in node '362a30'. Skipping!
# Property 'summary_embedding' already exists in node '1eee2e'. Skipping!
# Property 'summary_embedding' already exists in node '250fad'. Skipping!
# Property 'summary_embedding' already exists in node 'c63d79'. Skipping!
# Property 'summary_embedding' already exists in node '54fb95'. Skipping!
# Property 'summary_embedding' already exists in node 'e8f41f'. Skipping!
# Property 'summary_embedding' already exists in node '08573c'. Skipping!
# Property 'summary_embedding' already exists in node 'c19aa4'. Skipping!
# Property 'summary_embedding' already exists in node '11f261'. Skipping!
# Property 'summary_embedding' already exists in node '4a346b'. Skipping!
# Property 'summary_embedding' already exists in node '165128'. Skipping!
# Property 'summary_embedding' already exists in node '40c36c'. Skipping!
# Property 'summary_embedding' already exists in node 'e61e52'. Skipping!
# Property 'summary_embedding' already exists in node '93a2d4'. Skipping!
# Property 'summary_embedding' already exists in node '702f2a'. Skipping!
# Property 'summary_embedding' already exists in node '885658'. Skipping!
# Property 'summary_embedding' already exists in node 'c030eb'. Skipping!
# Property 'summary_embedding' already exists in node 'f29bec'. Skipping!
# Property 'summary_embedding' already exists in node 'd8f2bc'. Skipping!
# Property 'summary_embedding' already exists in node 'be3187'. Skipping!
# Property 'summary_embedding' already exists in node '246a10'. Skipping!
# Property 'summary_embedding' already exists in node 'c5d1d4'. Skipping!
# Property 'summary_embedding' already exists in node '288879'. Skipping!
# Property 'summary_embedding' already exists in node '92114a'. Skipping!
# Property 'summary_embedding' already exists in node 'f1def6'. Skipping!
# Property 'summary_embedding' already exists in node '8cf0f9'. Skipping!
# Property 'summary_embedding' already exists in node '12f195'. Skipping!
# Property 'summary_embedding' already exists in node '01473f'. Skipping!
# Property 'summary_embedding' already exists in node '2ae16f'. Skipping!
# Property 'summary_embedding' already exists in node '5549fb'. Skipping!
# Property 'summary_embedding' already exists in node 'fcd06a'. Skipping!
# Property 'summary_embedding' already exists in node 'f735b8'. Skipping!
# Property 'summary_embedding' already exists in node 'dbd342'. Skipping!
# Property 'summary_embedding' already exists in node '8451e2'. Skipping!
# Property 'summary_embedding' already exists in node '23facb'. Skipping!
# Property 'summary_embedding' already exists in node '6b1530'. Skipping!
# Property 'summary_embedding' already exists in node '46901b'. Skipping!
# Property 'summary_embedding' already exists in node 'c5643d'. Skipping!
# Property 'summary_embedding' already exists in node '7ad6ad'. Skipping!
# Property 'summary_embedding' already exists in node '5eee63'. Skipping!
# Property 'summary_embedding' already exists in node '8daf6a'. Skipping!
# Property 'summary_embedding' already exists in node 'e71349'. Skipping!
# Property 'summary_embedding' already exists in node '4e22e6'. Skipping!
# Property 'summary_embedding' already exists in node 'f49465'. Skipping!
# Property 'summary_embedding' already exists in node 'ac5796'. Skipping!
# Property 'summary_embedding' already exists in node 'da5d15'. Skipping!
# Property 'summary_embedding' already exists in node '47099c'. Skipping!
# Property 'summary_embedding' already exists in node '87b8e1'. Skipping!
# Property 'summary_embedding' already exists in node '5a0402'. Skipping!
# Property 'summary_embedding' already exists in node '8a3520'. Skipping!
# Property 'summary_embedding' already exists in node 'ecbf95'. Skipping!
# Property 'summary_embedding' already exists in node 'f1a443'. Skipping!
# Property 'summary_embedding' already exists in node 'cb2ce4'. Skipping!
# Property 'summary_embedding' already exists in node '50a335'. Skipping!
# Property 'summary_embedding' already exists in node '6b79cc'. Skipping!
# Property 'summary_embedding' already exists in node '542241'. Skipping!
# Property 'summary_embedding' already exists in node '33aaa7'. Skipping!
# Property 'summary_embedding' already exists in node '23af3e'. Skipping!
# Property 'summary_embedding' already exists in node 'de07c6'. Skipping!
# Property 'summary_embedding' already exists in node '54253c'. Skipping!
# Property 'summary_embedding' already exists in node '2a71fc'. Skipping!
# Property 'summary_embedding' already exists in node '41a571'. Skipping!
# Property 'summary_embedding' already exists in node '6db2ac'. Skipping!
# Property 'summary_embedding' already exists in node 'b23f44'. Skipping!
# Property 'summary_embedding' already exists in node '5d6e2d'. Skipping!
# Property 'summary_embedding' already exists in node 'ff615b'. Skipping!
# Property 'summary_embedding' already exists in node '039f38'. Skipping!
# Property 'summary_embedding' already exists in node '782ad7'. Skipping!
# Property 'summary_embedding' already exists in node 'cbca2b'. Skipping!
# Property 'summary_embedding' already exists in node '1c7cd7'. Skipping!
# Property 'summary_embedding' already exists in node '70cf05'. Skipping!
# Property 'summary_embedding' already exists in node 'bc02e9'. Skipping!
# Property 'summary_embedding' already exists in node '836d03'. Skipping!
# Property 'summary_embedding' already exists in node 'be3c66'. Skipping!
# Property 'summary_embedding' already exists in node 'db6036'. Skipping!
# Property 'summary_embedding' already exists in node '2d101d'. Skipping!
# Property 'summary_embedding' already exists in node 'e87756'. Skipping!
# Property 'summary_embedding' already exists in node '7753bb'. Skipping!
# Property 'summary_embedding' already exists in node '7979be'. Skipping!
# Property 'summary_embedding' already exists in node '5cfe4a'. Skipping!
# Property 'summary_embedding' already exists in node '634217'. Skipping!
# Property 'summary_embedding' already exists in node '9bc8d2'. Skipping!
# Property 'summary_embedding' already exists in node '08450e'. Skipping!
# Property 'summary_embedding' already exists in node 'f2f4d1'. Skipping!
# Property 'summary_embedding' already exists in node '8c9252'. Skipping!
# Property 'summary_embedding' already exists in node 'dc3cf8'. Skipping!
# Property 'summary_embedding' already exists in node '6fdf3e'. Skipping!
# Property 'summary_embedding' already exists in node '0446e8'. Skipping!
# Property 'summary_embedding' already exists in node '329f13'. Skipping!
# Property 'summary_embedding' already exists in node '95a732'. Skipping!
# Property 'summary_embedding' already exists in node '9f9758'. Skipping!
# Property 'summary_embedding' already exists in node '1dbbd2'. Skipping!
# Property 'summary_embedding' already exists in node 'df0783'. Skipping!
# Property 'summary_embedding' already exists in node '74de17'. Skipping!
# Property 'summary_embedding' already exists in node '97a6bf'. Skipping!
# Property 'summary_embedding' already exists in node '737fbd'. Skipping!
# Property 'summary_embedding' already exists in node 'cd191f'. Skipping!
# Property 'summary_embedding' already exists in node '3fd47c'. Skipping!
# Property 'summary_embedding' already exists in node '0c901b'. Skipping!
# Property 'summary_embedding' already exists in node '00ff03'. Skipping!
# Property 'summary_embedding' already exists in node '78422d'. Skipping!
# Property 'summary_embedding' already exists in node '2e72a6'. Skipping!
# Property 'summary_embedding' already exists in node '402e25'. Skipping!
# Property 'summary_embedding' already exists in node 'e063b8'. Skipping!
# Property 'summary_embedding' already exists in node '050e13'. Skipping!
# Property 'summary_embedding' already exists in node '9ff964'. Skipping!
# Property 'summary_embedding' already exists in node '32b4ff'. Skipping!
# Property 'summary_embedding' already exists in node '7143c5'. Skipping!
# Property 'summary_embedding' already exists in node 'a57316'. Skipping!
# Property 'summary_embedding' already exists in node '935b79'. Skipping!
# Property 'summary_embedding' already exists in node '1a9f16'. Skipping!
# Property 'summary_embedding' already exists in node 'debd2c'. Skipping!
# Property 'summary_embedding' already exists in node '6ec456'. Skipping!
# Property 'summary_embedding' already exists in node '1e1d89'. Skipping!
# Property 'summary_embedding' already exists in node '065514'. Skipping!
# Property 'summary_embedding' already exists in node '3c7616'. Skipping!
# Property 'summary_embedding' already exists in node '41e982'. Skipping!
# Property 'summary_embedding' already exists in node 'a8826d'. Skipping!
# Property 'summary_embedding' already exists in node '3bfcad'. Skipping!
# Property 'summary_embedding' already exists in node 'ac9579'. Skipping!
# Property 'summary_embedding' already exists in node '1b4cdb'. Skipping!
# Property 'summary_embedding' already exists in node '62884b'. Skipping!
# Property 'summary_embedding' already exists in node '1a4b2a'. Skipping!
# Property 'summary_embedding' already exists in node '1bbda9'. Skipping!
# Property 'summary_embedding' already exists in node 'bf4017'. Skipping!
# Property 'summary_embedding' already exists in node 'a314fa'. Skipping!
# Property 'summary_embedding' already exists in node 'f7ad45'. Skipping!
# Property 'summary_embedding' already exists in node '0f6004'. Skipping!
# Property 'summary_embedding' already exists in node '1d8694'. Skipping!
# Property 'summary_embedding' already exists in node 'b9daa6'. Skipping!
# Property 'summary_embedding' already exists in node '22811b'. Skipping!
# Property 'summary_embedding' already exists in node '3144ed'. Skipping!
# Property 'summary_embedding' already exists in node 'd04f8d'. Skipping!
# Property 'summary_embedding' already exists in node '6abe07'. Skipping!
# Property 'summary_embedding' already exists in node '78011e'. Skipping!
# Property 'summary_embedding' already exists in node 'edf5e8'. Skipping!
# Property 'summary_embedding' already exists in node '209693'. Skipping!
# Property 'summary_embedding' already exists in node '90643d'. Skipping!
# Property 'summary_embedding' already exists in node 'a274d8'. Skipping!
# Property 'summary_embedding' already exists in node '1e5dca'. Skipping!
# Property 'summary_embedding' already exists in node 'd88afb'. Skipping!
# Property 'summary_embedding' already exists in node '7ae90f'. Skipping!
# Property 'summary_embedding' already exists in node '4c4a88'. Skipping!
# Property 'summary_embedding' already exists in node '47fd70'. Skipping!
# Property 'summary_embedding' already exists in node 'ed1f88'. Skipping!
# Property 'summary_embedding' already exists in node '62e768'. Skipping!
# Property 'summary_embedding' already exists in node '75738a'. Skipping!
# Property 'summary_embedding' already exists in node 'd5dc3a'. Skipping!
# Property 'summary_embedding' already exists in node '8a600e'. Skipping!
# Property 'summary_embedding' already exists in node '507ee1'. Skipping!
# Property 'summary_embedding' already exists in node '4ea932'. Skipping!
# Property 'summary_embedding' already exists in node 'd9fab3'. Skipping!
# Property 'summary_embedding' already exists in node 'fe6baa'. Skipping!
# Property 'summary_embedding' already exists in node '7c7018'. Skipping!
# Property 'summary_embedding' already exists in node '8af988'. Skipping!
# Property 'summary_embedding' already exists in node '6e349d'. Skipping!
# Property 'summary_embedding' already exists in node 'e42b0b'. Skipping!
# Property 'summary_embedding' already exists in node 'cce4db'. Skipping!
# Property 'summary_embedding' already exists in node 'ef02b1'. Skipping!
# Property 'summary_embedding' already exists in node '8f8d78'. Skipping!
# Property 'summary_embedding' already exists in node '55c837'. Skipping!
# Property 'summary_embedding' already exists in node 'b3fadf'. Skipping!
# Property 'summary_embedding' already exists in node 'c1f910'. Skipping!
# Property 'summary_embedding' already exists in node 'bf16e7'. Skipping!
# Property 'summary_embedding' already exists in node '487979'. Skipping!
# Property 'summary_embedding' already exists in node '729295'. Skipping!
# Property 'summary_embedding' already exists in node 'b1511b'. Skipping!
# Property 'summary_embedding' already exists in node '79b707'. Skipping!
# Property 'summary_embedding' already exists in node '0f69e8'. Skipping!
# Property 'summary_embedding' already exists in node '4c2a84'. Skipping!
# Property 'summary_embedding' already exists in node 'd645fa'. Skipping!
# Property 'summary_embedding' already exists in node '160ad0'. Skipping!
# Property 'summary_embedding' already exists in node '9b2a7c'. Skipping!
# Property 'summary_embedding' already exists in node 'caafc6'. Skipping!
# Property 'summary_embedding' already exists in node '2b54dd'. Skipping!
# Property 'summary_embedding' already exists in node '7a9e18'. Skipping!
# Property 'summary_embedding' already exists in node '83c9b9'. Skipping!
# Property 'summary_embedding' already exists in node 'ce79ca'. Skipping!
# Property 'summary_embedding' already exists in node 'c97266'. Skipping!
# Property 'summary_embedding' already exists in node '806864'. Skipping!
# Property 'summary_embedding' already exists in node '725d28'. Skipping!
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/102 [00:00<?, ?it/s]

# %%
output_dataset = dataset.to_pandas()

# %%
output_dataset
# Out:
#                                             user_input  \
# 0    What sustainability initiatives has Alphabet I...
# 1    Why insurance not always enough for cover prod...
# 2     What tax challenges do online marketplaces face?
# 3    How is interest for Base Rate Loans computed w...
# 4    What is the role of the Administrative Agent's...
# ..                                                 ...
# 97   Wht is the role of Form 8-K in disclosing Tran...
# 98   How does the adoption of Azure IoT Edge contri...
# 99   How do the proceeds from debt issuances and th...
# 100  How does the non-transferability of SAs and th...
# 101  How have Alphabet Inc.'s capital expenditures ...
#
#                                     reference_contexts  \
# 0    [Ongoing Commitment to Sustainability Content:...
# 1    [Title: Claims, Litigation, Government Investi...
# 2    [We Face Additional Tax Liabilities and Collec...
# 3    [Title: 2.08 Computation of Interest and Fees ...
# 4    [2.10 Payments Generally; Administrative Agent...
# ..                                                 ...
# 97   [<1-hop>\n\nTransfer Restriction Agreements (d...
# 98   [<1-hop>\n\nOur increasing focus on cloud-base...
# 99   [<1-hop>\n\nDebt Proceeds We issue debt to tak...
# 100  [<1-hop>\n\nNon-Transferability of SAs Content...
# 101  [<1-hop>\n\nLeases Capital Expenditures Leases...
#
#                                              reference  \
# 0    Alphabet Inc. has implemented several sustaina...
# 1    Although liability insurance is maintained, it...
# 2    Online marketplaces face tax challenges such a...
# 3    Interest for Base Rate Loans, when the Base Ra...
# 4    The Administrative Agent's Office is responsib...
# ..                                                 ...
# 97   Form 8-K plays a role in disclosing updates su...
# 98   The adoption of Azure IoT Edge is integral to ...
# 99   The proceeds from debt issuances are used for ...
# 100  The non-transferability of SAs, as outlined in...
# 101  Between 2021 and 2023, Alphabet Inc.'s capital...
#
#                          synthesizer_name
# 0    single_hop_specifc_query_synthesizer
# 1    single_hop_specifc_query_synthesizer
# 2    single_hop_specifc_query_synthesizer
# 3    single_hop_specifc_query_synthesizer
# 4    single_hop_specifc_query_synthesizer
# ..                                    ...
# 97   multi_hop_specific_query_synthesizer
# 98   multi_hop_specific_query_synthesizer
# 99   multi_hop_specific_query_synthesizer
# 100  multi_hop_specific_query_synthesizer
# 101  multi_hop_specific_query_synthesizer
#
# [102 rows x 4 columns]
