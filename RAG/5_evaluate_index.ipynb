# %%
import os
from azure.identity import DefaultAzureCredential
credential = DefaultAzureCredential()

from dotenv import load_dotenv
load_dotenv(override=True) # take environment variables from .env.
# Out:
# True

# %%
import json
import pandas as pd

flow_output_dataframe = pd.read_json("instance_results.jsonl", lines=True)
flow_output_dataframe = flow_output_dataframe[['inputs.context','inputs.ground_truth','inputs.query','inputs.response']]
flow_output_dataframe = flow_output_dataframe[flow_output_dataframe["inputs.response"]!='The requested information is not available in the retrieved data. Please try another query or topic.'].reset_index(drop=True)
flow_output_dataframe = flow_output_dataframe.rename(columns={'inputs.context': 'context', 'inputs.ground_truth': 'ground_truth', 'inputs.query': 'query', 'inputs.response': 'response'})
flow_output_dataframe
# Out:
#                                               context  \
# 0   [{'content': 'Table of Contents\nreasons, incl...
# 1   [{'content': "Table of Contents\nOur digital c...
# 2   [{'content': "Alphabet Inc.\nTable of Contents...
# 3   [{'content': 'Table of Contents\nWe Face Risks...
# 4   [{'content': 'Exhibit A ALPHABET INC. CLAWBACK...
# 5   [{'content': 'Table of Contents\nAlphabet Inc....
# 6   [{'content': "Alphabet Inc.\nTable of Contents...
# 7   [{'content': '3\nCONTRACT OR TORT OR OTHERWISE...
# 8   [{'content': '(stating that it is a "notice of...
# 9   [{'content': 'Table of Contents\nand related t...
# 10  [{'content': 'and information as it shall from...
# 11  [{'content': "Table of Contents\nAlphabet Inc....
# 12  [{'content': 'Exhibit A ALPHABET INC. CLAWBACK...
# 13  [{'content': "PART I\nItem 1\nThe ability to c...
# 14  [{'content': "Special Approval for Change in C...
# 15  [{'content': 'Table of Contents\nFulfillment\n...
# 16  [{'content': "Alphabet Inc.\nTable of Contents...
# 17  [{'content': "Alphabet Inc.\nTable of Contents...
# 18  [{'content': "shall be treated as made in the ...
# 19  [{'content': '1.07 Times of Day. Unless otherw...
# 20  [{'content': 'Schedule A to Performance Stock ...
# 21  [{'content': 'PART II\nItem 7\nOperating incom...
# 22  [{'content': 'Alphabet Inc.\nTable of Contents...
# 23  [{'content': "continuation of any Eurocurrency...
# 24  [{'content': "PARTI Item 2\n. Search and news ...
# 25  [{'content': "Alphabet Inc.\nTable of Contents...
# 26  [{'content': 'Table of Contents\nAlphabet Inc....
# 27  [{'content': '"Attributable Indebtedness" mean...
# 28  [{'content': 'resignation (or such earlier day...
#
#                                          ground_truth  \
# 0   ['Our International Operations Expose Us to a ...
# 1   ['Title: Operating Risks Content: Table of Con...
# 2   ['The Loss of Key Senior Management Personnel ...
# 3   ["Title: Risks Related to Data Security, Syste...
# 4   ['Title: Claims, Litigation, Government Invest...
# 5   ['Risk Factors." Overview Our primary source o...
# 6   ['<1-hop>\n\nNote 10 - SEGMENT INFORMATION Con...
# 7   ["<1-hop>\n\nTitle: Risk Factors Content: Tabl...
# 8   ['<1-hop>\n\nTitle: Notice of Default Content:...
# 9   ['<1-hop>\n\nTitle: Cost of Sales and Operatin...
# 10  ['<1-hop>\n\nTitle: ARTICLE IX. LOAN DOCUMENTS...
# 11  ["<1-hop>\n\nTitle: Risk Factors Content: Alph...
# 12  ["<1-hop>\n\nTitle: General Risks Content: Tab...
# 13  ['<1-hop>\n\nTitle: Intellectual Property and ...
# 14  ["<1-hop>\n\nTitle: General Risks Content: Tab...
# 15  ['<1-hop>\n\nTitle: Cost of Sales and Operatin...
# 16  ['<1-hop>\n\nTitle: Board of Directors and Ris...
# 17  ["<1-hop>\n\nTitle: Risk Factors Content: Tabl...
# 18  ["<1-hop>\n\nTitle: Payments and Funding Provi...
# 19  ["<1-hop>\n\nTitle: 2.08 Computation of Intere...
# 20  ["<1-hop>\n\nTitle: Tax-Related Items and Righ...
# 21  ["<1-hop>\n\nTitle: ITEM 1A. RISK FACTORS Cont...
# 22  ["<1-hop>\n\nOur digital content offerings dep...
# 23  ['<1-hop>\n\n"ERISA Event" means (a) a Reporta...
# 24  ['<1-hop>\n\nTitle: Operating Risks Content: T...
# 25  ['<1-hop>\n\nTitle: Data Privacy and Consent i...
# 26  ['<1-hop>\n\nThe Loss of Key Senior Management...
# 27  ['<1-hop>\n\n"Bail-In Action" means the exerci...
# 28  ['<1-hop>\n\nTreatment of Certain Information;...
#
#                                                 query  \
# 0   What are some of the risks associated with int...
# 1   Wht are the risks assoociated with holding cas...
# 2   Why is it challenging for businesses to hire a...
# 3   How can supplier relationships impact the oper...
# 4   How do governments and regulatory authorities ...
# 5   What be free cash flows and how they help busi...
# 6   How do tax contingencies and segment performan...
# 7   How do the risks associated with artificial in...
# 8   What happens when the Administrative Agent res...
# 9   How do fulfillment costs and marketing costs i...
# 10  What is the role of the Administrative Agent i...
# 11  What are the risks associated with cyber attac...
# 12  How do Alphabet Inc.'s stockholder rights prov...
# 13  How does Alphabet Inc.'s focus on innovation a...
# 14  How Delaware anti-takeover provisions affect s...
# 15  How does Amazon's investment in technology and...
# 16  Who on the Board of Directors might help with ...
# 17  How do the risks associated with artificial in...
# 18  What happens if a payment is due on a day that...
# 19  How are interest rates and fees calculated for...
# 20  What are the tax-related obligations and restr...
# 21  How does the reliance on advertisers for reven...
# 22  How do fluctuations in foreign exchange rates ...
# 23  What is the EURIBO Rate, and how does its unav...
# 24  How do fluctuations in the U.S. Dollar impact ...
# 25  How does the agreement ensure that an employee...
# 26  Why suppliers important and what risks with no...
# 27  What is the role of Bail-In Legislation in the...
# 28  Wht happns to the Adminstrative Agent's duties...
#
#                                              response
# 0   International operations expose companies to a...
# 1   Holding cash equivalents in British Pounds (GB...
# 2   Businesses face challenges in hiring and retai...
# 3   Supplier relationships can significantly impac...
# 4   Governments and regulatory authorities impact ...
# 5   Free cash flow represents the cash a company g...
# 6   Tax contingencies and segment performance eval...
# 7   The risks associated with artificial intellige...
# 8   When the Administrative Agent resigns, the fol...
# 9   Fulfillment costs and marketing costs signific...
# 10  The **Administrative Agent** plays a crucial r...
# 11  Alphabet Inc.'s risk factors highlight several...
# 12  Alphabet Inc.'s stockholder rights provisions ...
# 13  Alphabet Inc.'s focus on innovation and techno...
# 14  Delaware's anti-takeover provisions, particula...
# 15  Amazon's investment in technology and content ...
# 16  From the Board of Directors, **Indra K. Nooyi*...
# 17  The retrieved documents provide insights into ...
# 18  If a payment is due on a day that is not a Bus...
# 19  Interest rates and fees for loans denominated ...
# 20  ### Tax-Related Obligations and Restrictions\n...
# 21  Alphabet Inc. relies significantly on advertis...
# 22  Fluctuations in foreign exchange rates signifi...
# 23  The EURIBO Rate refers to the euro interbank o...
# 24  Fluctuations in the U.S. Dollar can significan...
# 25  The agreement ensures that an employee's conse...
# 26  Suppliers are crucial because they provide the...
# 27  Bail-In Legislation plays a critical role in t...
# 28  After the resignation or removal of the Admini...

# %%
flow_output_dataframe['context'][0]
# Out:
# '[{\'content\': \'Table of Contents\\nreasons, including if we are unable to realize the expected benefits of new technologies or if we do not successfully plan or execute new strategies, which could harm our business or damage our reputation.\\nOur International Operations Expose Us to a Number of Risks\\nOur international activities are significant to our revenues and profits, and we plan to further expand internationally. In certain international market segments, we have relatively little operating experience and may not benefit from any first-to-market advantages or otherwise succeed. It is costly to establish, develop, and maintain international operations and stores, and promote our brand internationally. Our international operations may not become profitable on a sustained basis.\\nIn addition to risks described elsewhere in this section, our international sales and operations are subject to a number of risks, including:\\n· local economic and political conditions;\\n· government regulation (such as regulation of our product and service offerings and of competition); restrictive governmental actions (such as trade protection measures, including export duties and quotas and custom duties and tariffs); nationalization; and restrictions on foreign ownership;\\n· restrictions on sales or distribution of certain products or services and uncertainty regarding liability for products, services, and content, including uncertainty as a result of less Internet-friendly legal systems, local laws, lack of legal precedent, and varying rules, regulations, and practices regarding the physical and digital distribution of media products and enforcement of intellectual property rights;\\n· business licensing or certification requirements, such as for imports, exports, web services, and electronic devices;\\n· limitations on the repatriation and investment of funds and foreign currency exchange restrictions;\\n· limited fulfillment and technology infrastructure;\\n· shorter payable and longer receivable cycles and the resultant negative impact on cash flow;\\n· laws and regulations regarding privacy, data use, data protection, data security, data localization, network security, consumer protection, payments, advertising, and restrictions on pricing or discounts;\\n· lower levels of use of the Internet;\\n· lower levels of consumer spending and fewer opportunities for growth compared to the U.S .;\\n· lower levels of credit card usage and increased payment risk;\\n· difficulty in staffing, developing, and managing foreign operations as a result of distance, language, and cultural differences;\\n· different employee/employer relationships and the existence of works councils and labor unions;\\n· compliance with the U.S. Foreign Corrupt Practices Act and other applicable U.S. and foreign laws prohibiting corrupt payments to government officials and other third parties;\\n· laws and policies of the U.S. and other jurisdictions affecting trade, foreign investment, loans, and taxes; and\\n· geopolitical events, including war and terrorism.\\nAs international physical, e-commerce, and omnichannel retail, cloud services, and other services grow, competition will intensify, including through adoption of evolving business models. Local companies may have a substantial competitive advantage because of their greater understanding of, and focus on, the local customer, as well as their more established local brand names. The inability to hire, train, retain, and manage sufficient required personnel may limit our international growth.\\nThe People\\\'s Republic of China ("PRC") and India regulate Amazon\\\'s and its affiliates\\\' businesses and operations in country through regulations and license requirements that may restrict (i) foreign investment in and operation of the Internet, IT infrastructure, data centers, retail, delivery, and other sectors, (ii) Internet content, and (iii) the sale of media and other products and services. For example, in or ...

# %%
output_path = "data.jsonl"

with open(output_path, "w") as f:
    f.write(flow_output_dataframe.to_json(orient='records', lines=True, force_ascii=False))

# %% [markdown]
# ### Basic evaluator

# %%
# Initialize Azure AI project and Azure OpenAI conncetion with your environment variables
azure_ai_project = {
    "subscription_id": os.environ.get("AZURE_SUBSCRIPTION_ID"),
    "resource_group_name": os.environ.get("AZURE_RESOURCE_GROUP"),
    "project_name": os.environ.get("AZURE_PROJECT_NAME"),
}

model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": os.environ.get("AZURE_OPENAI_API_KEY"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_CHATGPT_DEPLOYMENT"),
    "api_version": os.environ.get("AZURE_OPENAI_API_VERSION"),
}

from azure.ai.evaluation import GroundednessProEvaluator, GroundednessEvaluator

# Initialzing Groundedness and Groundedness Pro evaluators
groundedness_eval = GroundednessEvaluator(model_config)
groundedness_pro_eval = GroundednessProEvaluator(azure_ai_project=azure_ai_project, credential=credential)

query_response = dict(
    query="Which tent is the most waterproof?",
    context="The Alpine Explorer Tent is the most water-proof of all tents available.",
    response="The Alpine Explorer Tent is the most waterproof."
)

# Running Groundedness Evaluator on a query and response pair
groundedness_score = groundedness_eval(
    **query_response
)
print(groundedness_score)
# Out:
# {'groundedness': 5.0, 'gpt_groundedness': 5.0, 'groundedness_reason': 'The response is fully correct and complete, directly addressing the query with precise information from the context.'}
# {'answer_length': 27}
# 2025-01-30 13:31:43 -0500   21200 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-01-30 13:31:49 -0500   21200 execution.bulk     INFO     Finished 2 / 29 lines.
# 2025-01-30 13:31:49 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.03 seconds. Estimated time for incomplete lines: 81.81 seconds.
# 2025-01-30 13:31:50 -0500   21200 execution.bulk     INFO     Finished 5 / 29 lines.
# 2025-01-30 13:31:50 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.34 seconds. Estimated time for incomplete lines: 32.16 seconds.
# 2025-01-30 13:31:51 -0500   21200 execution.bulk     INFO     Finished 9 / 29 lines.
# 2025-01-30 13:31:51 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.88 seconds. Estimated time for incomplete lines: 17.6 seconds.
# 2025-01-30 13:31:52 -0500   21200 execution.bulk     INFO     Finished 10 / 29 lines.
# 2025-01-30 13:31:52 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.85 seconds. Estimated time for incomplete lines: 16.15 seconds.
# 2025-01-30 13:31:54 -0500   21200 execution.bulk     INFO     Finished 12 / 29 lines.
# 2025-01-30 13:31:54 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.9 seconds. Estimated time for incomplete lines: 15.3 seconds.
# 2025-01-30 13:31:55 -0500   21200 execution.bulk     INFO     Finished 14 / 29 lines.
# 2025-01-30 13:31:55 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.81 seconds. Estimated time for incomplete lines: 12.15 seconds.
# 2025-01-30 13:31:55 -0500   21200 execution.bulk     INFO     Finished 16 / 29 lines.
# 2025-01-30 13:31:55 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.75 seconds. Estimated time for incomplete lines: 9.75 seconds.
# 2025-01-30 13:31:57 -0500   21200 execution.bulk     INFO     Finished 18 / 29 lines.
# 2025-01-30 13:31:57 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.74 seconds. Estimated time for incomplete lines: 8.14 seconds.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.72 seconds. Estimated time for incomplete lines: 6.48 seconds.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.67 seconds. Estimated time for incomplete lines: 4.69 seconds.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:31:58 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.63 seconds. Estimated time for incomplete lines: 3.15 seconds.
# 2025-01-30 13:31:59 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:31:59 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 1.77 seconds.
# 2025-01-30 13:32:00 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:32:00 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 0.59 seconds.
# 2025-01-30 13:32:00 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:32:00 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.57 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nv0uge99_20250130_133143_498457"
# Run status: "Completed"
# Start time: "2025-01-30 13:31:43.490451-05:00"
# Duration: "0:00:17.613673"
# Output path: "C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nv0uge99_20250130_133143_498457"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:17.613673",
#         "completed_lines": 29,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\jomedin\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nv0uge99_20250130_133143_498457"
#     }
# }
#
# ====================================================
#
# Evaluation results saved to "C:\Users\jomedin\Documents\AzureAIAgents\myevalresults.json".

# %% [markdown]
# ### Custom Evaluator

# %%
from answer_len.answer_length import AnswerLengthEvaluator

answer_length_evaluator = AnswerLengthEvaluator()
answer_length = answer_length_evaluator(answer="What is the speed of light?")

answer_length
# Out:
# {'answer_length': 27}

# %% [markdown]
# ### Local Evaluatior on Datasets

# %%
from azure.ai.evaluation import evaluate

result = evaluate(
    data="data.jsonl", # provide your data here
    evaluators={
        "groundedness": groundedness_eval,
        "answer_length": answer_length_evaluator,
    },
    # column mapping
    evaluator_config={
        "groundedness": {
            "column_mapping": {
                "query": "${data.query}",
                "context": "${data.context}",
                "response": "${data.response}"
            } 
        },
        "answer_length": {
            "column_mapping": {
                "answer": "${data.response}",
            } 
        }
    },
    # Optionally provide your Azure AI project information to track your evaluation results in your Azure AI project
    #azure_ai_project = azure_ai_project,
    # Optionally provide an output path to dump a json of metric summary, row level data and metric and Azure AI project URL
    output_path="./myevalresults.json"
)
# Out:
# [2025-01-30 13:57:08 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:57:08 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:57:08 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m9iynfbk_20250130_135708_236404, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m9iynfbk_20250130_135708_236404\logs.txt
# [2025-01-30 13:57:08 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run answer_len_answer_length_answerlengthevaluator_meca6tnj_20250130_135708_249667, log path: C:\Users\jomedin\.promptflow\.runs\answer_len_answer_length_answerlengthevaluator_meca6tnj_20250130_135708_249667\logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m9iynfbk_20250130_135708_236404
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=answer_len_answer_length_answerlengthevaluator_meca6tnj_20250130_135708_249667
# 2025-01-30 13:57:23 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:57:23 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.71 seconds. Estimated time for incomplete lines: 6.39 seconds.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.74 seconds. Estimated time for incomplete lines: 5.18 seconds.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.69 seconds. Estimated time for incomplete lines: 3.45 seconds.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:57:25 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.64 seconds. Estimated time for incomplete lines: 1.92 seconds.
# 2025-01-30 13:57:26 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:57:26 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.62 seconds. Estimated time for incomplete lines: 0.62 seconds.
# 2025-01-30 13:57:26 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:57:26 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 0.6 seconds. Estimated time for incomplete lines: 0.0 seconds.

# %%
import json

with open("./myevalresults.json", "r") as read_file:
    data = json.load(read_file)

data['metrics']
# Out:
# {'groundedness.groundedness': 4.793103448275862,
#  'groundedness.gpt_groundedness': 4.793103448275862,
#  'answer_length.answer_length': 1505.551724137931}

# %%
## https://github.com/Azure-Samples/azureai-samples/blob/main/scenarios/evaluate/Supported_Evaluation_Metrics/AI_Judge_Evaluators_Quality/AI_Judge_Evaluators_Quality.ipynb

# %%
import pathlib

from azure.ai.evaluation import evaluate
from azure.ai.evaluation import (
    ContentSafetyEvaluator,
    RelevanceEvaluator,
    CoherenceEvaluator,
    GroundednessEvaluator,
    FluencyEvaluator,
    SimilarityEvaluator,
    RetrievalEvaluator,
)

content_safety_evaluator = ContentSafetyEvaluator(
    azure_ai_project=azure_ai_project, credential=DefaultAzureCredential()
)
relevance_evaluator = RelevanceEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
similarity_evaluator = SimilarityEvaluator(model_config)
retrieval_evaluator = RetrievalEvaluator(model_config)

path = "data.jsonl"

results = evaluate(
    evaluation_name="Eval-Run-" + "-" + model_config["azure_deployment"].title(),
    data=path,
    evaluators={
        "content_safety": content_safety_evaluator,
        "coherence": coherence_evaluator,
        "relevance": relevance_evaluator,
        "groundedness": groundedness_evaluator,
        "fluency": fluency_evaluator,
        "similarity": similarity_evaluator,
        "retrieval": retrieval_evaluator,
    },
    evaluator_config={
        "content_safety": {"column_mapping": {"query": "${data.query}", "response": "${data.response}"}},
        "coherence": {"column_mapping": {"response": "${data.response}", "query": "${data.query}"}},
        "relevance": {
            "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "groundedness": {
            "column_mapping": {
                "response": "${data.response}",
                "context": "${data.context}",
                "query": "${data.query}",
            }
        },
        "fluency": {
            "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "similarity": {
            "column_mapping": {"ground_truth": "${data.ground_truth}", "response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "retrieval":{
            "column_mapping": {"context": "${data.context}", "query": "${data.query}"}
        }
    },
    output_path="./combined_results.json"
)
# Out:
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_19jzuv0_20250130_134715_705730, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_19jzuv0_20250130_134715_705730\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_tovcwj26_20250130_134715_699238, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_tovcwj26_20250130_134715_699238\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_mjsnhqov_20250130_134715_705730, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_mjsnhqov_20250130_134715_705730\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_jk_uw9_l_20250130_134715_699238, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_jk_uw9_l_20250130_134715_699238\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ob7128f9_20250130_134715_699238, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ob7128f9_20250130_134715_699238\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h3rcxtc6_20250130_134715_705730, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h3rcxtc6_20250130_134715_705730\logs.txt
# [2025-01-30 13:47:16 -0500][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7kms1azu_20250130_134715_699238, log path: C:\Users\jomedin\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7kms1azu_20250130_134715_699238\logs.txt
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_19jzuv0_20250130_134715_705730
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_mjsnhqov_20250130_134715_705730
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_tovcwj26_20250130_134715_699238
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ob7128f9_20250130_134715_699238
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h3rcxtc6_20250130_134715_705730
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_jk_uw9_l_20250130_134715_699238
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7kms1azu_20250130_134715_699238
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:42 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 43 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=43, Back off 43.0 seconds for retry.
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 42 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:43 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=42, Back off 42.0 seconds for retry.
# 2025-01-30 13:47:44 -0500   21200 execution.bulk     INFO     Finished 18 / 29 lines.
# 2025-01-30 13:47:44 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.54 seconds. Estimated time for incomplete lines: 16.94 seconds.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Finished 19 / 29 lines.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 15.1 seconds.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.43 seconds. Estimated time for incomplete lines: 12.87 seconds.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:47:45 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.44 seconds. Estimated time for incomplete lines: 12.96 seconds.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 40 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:45 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=40, Back off 40.0 seconds for retry.
# 2025-01-30 13:47:47 -0500   21200 execution.bulk     INFO     Finished 12 / 29 lines.
# 2025-01-30 13:47:47 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.54 seconds. Estimated time for incomplete lines: 43.18 seconds.
# [2025-01-30 13:47:47 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 39 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:47 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=39, Back off 39.0 seconds for retry.
# [2025-01-30 13:47:47 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 39 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:47 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=39, Back off 39.0 seconds for retry.
# 2025-01-30 13:47:50 -0500   21200 execution.bulk     INFO     Finished 17 / 29 lines.
# 2025-01-30 13:47:50 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.0 seconds. Estimated time for incomplete lines: 24.0 seconds.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Finished 19 / 29 lines.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.84 seconds. Estimated time for incomplete lines: 18.4 seconds.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.75 seconds. Estimated time for incomplete lines: 15.75 seconds.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:51 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Finished 19 / 29 lines.
# 2025-01-30 13:47:51 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 1.86 seconds. Estimated time for incomplete lines: 18.6 seconds.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-10-21 have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 34 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2025-01-30 13:47:52 -0500][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=34, Back off 34.0 seconds for retry.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.6 seconds. Estimated time for incomplete lines: 25.2 seconds.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.3 seconds. Estimated time for incomplete lines: 16.5 seconds.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.05 seconds. Estimated time for incomplete lines: 9.15 seconds.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:48:35 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.61 seconds. Estimated time for incomplete lines: 25.27 seconds.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.33 seconds. Estimated time for incomplete lines: 16.65 seconds.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.07 seconds. Estimated time for incomplete lines: 9.21 seconds.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.86 seconds. Estimated time for incomplete lines: 2.86 seconds.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:48:36 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.86 seconds. Estimated time for incomplete lines: 2.86 seconds.
# 2025-01-30 13:48:37 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:37 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.79 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-01-30 13:48:38 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:38 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.84 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-01-30 13:48:38 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:48:38 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.75 seconds. Estimated time for incomplete lines: 26.25 seconds.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.44 seconds. Estimated time for incomplete lines: 17.2 seconds.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.18 seconds. Estimated time for incomplete lines: 9.54 seconds.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.96 seconds. Estimated time for incomplete lines: 2.96 seconds.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 4.17 seconds. Estimated time for incomplete lines: 37.53 seconds.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:39 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.88 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.79 seconds. Estimated time for incomplete lines: 26.53 seconds.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.49 seconds. Estimated time for incomplete lines: 17.45 seconds.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:48:40 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.24 seconds. Estimated time for incomplete lines: 9.72 seconds.
# 2025-01-30 13:48:41 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:48:41 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.03 seconds. Estimated time for incomplete lines: 3.03 seconds.
# 2025-01-30 13:48:41 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:41 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 2.93 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-01-30 13:48:44 -0500   21200 execution.bulk     INFO     Finished 20 / 29 lines.
# 2025-01-30 13:48:44 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 4.38 seconds. Estimated time for incomplete lines: 39.42 seconds.
# 2025-01-30 13:48:44 -0500   21200 execution.bulk     INFO     Finished 22 / 29 lines.
# 2025-01-30 13:48:44 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.98 seconds. Estimated time for incomplete lines: 27.86 seconds.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Finished 24 / 29 lines.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.75 seconds. Estimated time for incomplete lines: 18.75 seconds.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.11 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-01-30 13:48:46 -0500   21200 execution          ERROR    29/29 flow run failed, indexes: [23,16,26,5,9,2,18,24,14,3,28,17,27,21,19,6,11,10,15,13,25,20,1,7,12,22,8,0,4], exception of index 23: (UserError) The needed capability 'content harm' is not supported by the RAI service in this region.
# Visit https://aka.ms/azsdk/python/evaluation/safetyevaluator/troubleshoot to troubleshoot this issue.
# [2025-01-30 13:48:46 -0500][promptflow._sdk._orchestrator.run_submitter][WARNING] - 29 out of 29 runs failed in batch run.
#  Please check out C:/Users/jomedin/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ob7128f9_20250130_134715_699238 for more details.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Finished 26 / 29 lines.
# 2025-01-30 13:48:46 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.48 seconds. Estimated time for incomplete lines: 10.44 seconds.
# 2025-01-30 13:48:47 -0500   21200 execution.bulk     INFO     Finished 28 / 29 lines.
# 2025-01-30 13:48:47 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.24 seconds. Estimated time for incomplete lines: 3.24 seconds.
# 2025-01-30 13:48:48 -0500   21200 execution.bulk     INFO     Finished 29 / 29 lines.
# 2025-01-30 13:48:48 -0500   21200 execution.bulk     INFO     Average execution time for completed lines: 3.16 seconds. Estimated time for incomplete lines: 0.0 seconds.

# %%
import json

with open("./combined_results.json", "r") as read_file:
    data = json.load(read_file)

data['metrics']
# Out:
# {'coherence.coherence': 4.275862068965517,
#  'coherence.gpt_coherence': 4.275862068965517,
#  'relevance.relevance': 4.517241379310345,
#  'relevance.gpt_relevance': 4.517241379310345,
#  'groundedness.groundedness': 4.137931034482759,
#  'groundedness.gpt_groundedness': 4.137931034482759,
#  'fluency.fluency': 4.103448275862069,
#  'fluency.gpt_fluency': 4.103448275862069,
#  'similarity.similarity': 3.7586206896551726,
#  'similarity.gpt_similarity': 3.7586206896551726,
#  'retrieval.retrieval': 2.6206896551724137,
#  'retrieval.gpt_retrieval': 2.6206896551724137}

# %%
pd.DataFrame(data['rows']).head(10)
# Out:
#                                       inputs.context  \
# 0  [{'content': 'Table of Contents\nreasons, incl...
# 1  [{'content': "Table of Contents\nOur digital c...
# 2  [{'content': "Alphabet Inc.\nTable of Contents...
# 3  [{'content': 'Table of Contents\nWe Face Risks...
# 4  [{'content': 'Exhibit A ALPHABET INC. CLAWBACK...
# 5  [{'content': 'Table of Contents\nAlphabet Inc....
# 6  [{'content': "Alphabet Inc.\nTable of Contents...
# 7  [{'content': '3\nCONTRACT OR TORT OR OTHERWISE...
# 8  [{'content': '(stating that it is a "notice of...
# 9  [{'content': 'Table of Contents\nand related t...
#
#                                  inputs.ground_truth  \
# 0  ['Our International Operations Expose Us to a ...
# 1  ['Title: Operating Risks Content: Table of Con...
# 2  ['The Loss of Key Senior Management Personnel ...
# 3  ["Title: Risks Related to Data Security, Syste...
# 4  ['Title: Claims, Litigation, Government Invest...
# 5  ['Risk Factors." Overview Our primary source o...
# 6  ['<1-hop>\n\nNote 10 - SEGMENT INFORMATION Con...
# 7  ["<1-hop>\n\nTitle: Risk Factors Content: Tabl...
# 8  ['<1-hop>\n\nTitle: Notice of Default Content:...
# 9  ['<1-hop>\n\nTitle: Cost of Sales and Operatin...
#
#                                         inputs.query  \
# 0  What are some of the risks associated with int...
# 1  Wht are the risks assoociated with holding cas...
# 2  Why is it challenging for businesses to hire a...
# 3  How can supplier relationships impact the oper...
# 4  How do governments and regulatory authorities ...
# 5  What be free cash flows and how they help busi...
# 6  How do tax contingencies and segment performan...
# 7  How do the risks associated with artificial in...
# 8  What happens when the Administrative Agent res...
# 9  How do fulfillment costs and marketing costs i...
#
#                                      inputs.response  \
# 0  International operations expose companies to a...
# 1  Holding cash equivalents in British Pounds (GB...
# 2  Businesses face challenges in hiring and retai...
# 3  Supplier relationships can significantly impac...
# 4  Governments and regulatory authorities impact ...
# 5  Free cash flow represents the cash a company g...
# 6  Tax contingencies and segment performance eval...
# 7  The risks associated with artificial intellige...
# 8  When the Administrative Agent resigns, the fol...
# 9  Fulfillment costs and marketing costs signific...
#
#    outputs.coherence.coherence  outputs.coherence.gpt_coherence  \
# 0                            5                                5
# 1                            4                                4
# 2                            4                                4
# 3                            5                                5
# 4                            4                                4
# 5                            5                                5
# 6                            4                                4
# 7                            4                                4
# 8                            4                                4
# 9                            5                                5
#
#                   outputs.coherence.coherence_reason  \
# 0  The RESPONSE is coherent, well-organized, and ...
# 1  The RESPONSE is coherent and effectively addre...
# 2  The RESPONSE is coherent and effectively addre...
# 3  The RESPONSE is coherent, well-structured, and...
# 4  The RESPONSE is coherent, well-organized, and ...
# 5  The RESPONSE is coherent, logically structured...
# 6  The RESPONSE is coherent, logically organized,...
# 7  The RESPONSE is coherent, well-organized, and ...
# 8  The RESPONSE is coherent, well-organized, and ...
# 9  The RESPONSE is coherent, well-structured, and...
#
#    outputs.relevance.relevance  outputs.relevance.gpt_relevance  \
# 0                            4                                4
# 1                            4                                4
# 2                            4                                4
# 3                            5                                5
# 4                            5                                5
# 5                            4                                4
# 6                            4                                4
# 7                            5                                5
# 8                            5                                5
# 9                            5                                5
#
#                   outputs.relevance.relevance_reason  ...  \
# 0  The RESPONSE fully addresses the QUERY with ac...  ...
# 1  The RESPONSE fully addresses the QUERY with ac...  ...
# 2  The RESPONSE fully addresses the QUERY with ac...  ...
# 3  The RESPONSE fully addresses the QUERY with ac...  ...
# 4  The RESPONSE fully addresses the QUERY with ac...  ...
# 5  The RESPONSE fully addresses the QUERY with ac...  ...
# 6  The RESPONSE fully addresses the QUERY with ac...  ...
# 7  The RESPONSE fully addresses the QUERY with ac...  ...
# 8  The RESPONSE fully addresses the QUERY with ac...  ...
# 9  The RESPONSE fully addresses the QUERY with ac...  ...
#
#    outputs.groundedness.gpt_groundedness  \
# 0                                      3
# 1                                      5
# 2                                      5
# 3                                      5
# 4                                      5
# 5                                      3
# 6                                      3
# 7                                      3
# 8                                      3
# 9                                      5
#
#             outputs.groundedness.groundedness_reason outputs.fluency.fluency  \
# 0  The RESPONSE is accurate in its use of informa...                       4
# 1  The RESPONSE is entirely based on the CONTEXT,...                       4
# 2  The RESPONSE is entirely based on the CONTEXT,...                       4
# 3  The RESPONSE is fully grounded and complete, a...                       4
# 4  The RESPONSE is entirely based on the CONTEXT,...                       4
# 5  The RESPONSE is accurate in its description of...                       4
# 6  The RESPONSE is accurate in discussing tax con...                       4
# 7  The RESPONSE is accurate and aligns with the C...                       5
# 8  The RESPONSE is mostly grounded in the CONTEXT...                       4
# 9  The RESPONSE is entirely based on the CONTEXT,...                       4
#
#    outputs.fluency.gpt_fluency  \
# 0                            4
# 1                            4
# 2                            4
# 3                            4
# 4                            4
# 5                            4
# 6                            4
# 7                            5
# 8                            4
# 9                            4
#
#                       outputs.fluency.fluency_reason  \
# 0  The RESPONSE is well-articulated, grammaticall...
# 1  The RESPONSE is well-articulated, with good gr...
# 2  The RESPONSE is well-articulated, with good gr...
# 3  The RESPONSE is well-articulated, with good gr...
# 4  The RESPONSE is well-written, with strong gram...
# 5  The RESPONSE is well-articulated, with good gr...
# 6  The RESPONSE is well-articulated, with good co...
# 7  The RESPONSE deserves a high score because it ...
# 8  The RESPONSE is well-written, coherent, and de...
# 9  The RESPONSE is well-articulated, grammaticall...
#
#   outputs.similarity.similarity  outputs.similarity.gpt_similarity  \
# 0                             4                                  4
# 1                             3                                  3
# 2                             3                                  3
# 3                             3                                  3
# 4                             3                                  3
# 5                             3                                  3
# 6                             3                                  3
# 7                             4                                  4
# 8                             4                                  4
# 9                             5                                  5
#
#    outputs.retrieval.retrieval  outputs.retrieval.gpt_retrieval  \
# 0                            5                                5
# 1                            3                                3
# 2                            2                                2
# 3                            2                                2
# 4                            2                                2
# 5                            2                                2
# 6                            2                                2
# 7                            2                                2
# 8                            3                                3
# 9                            4                                4
#
#                   outputs.retrieval.retrieval_reason
# 0  The first two chunks are highly relevant and w...
# 1  The context contains relevant information abou...
# 2  The context is partially relevant but poorly r...
# 3  The context contains one relevant chunk at the...
# 4  The context contains relevant information abou...
# 5  The input data should get this score because w...
# 6  The contexts are partially relevant as they di...
# 7  The context contains partially relevant inform...
# 8  The context contains relevant information but ...
# 9  The input data should get this score because t...
#
# [10 rows x 21 columns]
